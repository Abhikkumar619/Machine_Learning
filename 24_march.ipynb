# %% [markdown]
# Q1. What are the key features of the wine quality data set? Discuss the importance of each feature in
# predicting the quality of wine.

# %%
"""
The key features of wine quality data set are : fixed acidity, citric acid, sulphates, and alcohol.

The importance of each features in predicting the quality of wine are: 
1. Between the fixed acidity and quality their is 0.12 weak positive correlation. 
2. beteeen the volatile acidity and quality their is -0.4 correlation which means as the increasing the volatile acidity decrease the quality of wine.
3. between the citric acid and and quality of wine there is 0.23 corrleation, increase the citric acid little bit increase the quality of wine.
3. residual sugar is 0.014 corrleation as the increase the residaul sugar negligable effect in quality of sugar.
4. chlorides is -0.13 correlation as the increase the chloride decrease the quality of wine.
4. free sulfur dioxide is -0.05 corealted with quality of wine as the increase the of sulfur dioxide may negligable amount of decrease the quality of 
5. total suilfurt dioxide is -0.18  corelated with quality of wine as decrease the amount of dioxide little bit improve the quality of wine.
6. density as the increase the density decrease the quality of wine. 
7. ph value is -0.055 negative correlation with quality .
8. sulphates and alcohol are 0.25 and 0.48 highly correlation with quality of wine once the increase the alchol and sulphates increase the 
   quality of wine.
"""

# %% [raw]
# Q2. How did you handle missing data in the wine quality data set during the feature engineering process?
# Discuss the advantages and disadvantages of different imputation techniques.

# %%
"""
Handling the missing data in wine quality data set by mean, medium and mode imputation. 

Advantage of Imputation technique in wine quality dataset.
1. Imputation technique aim to preserve the realtionship between variable in the dataset. 
   by fitlling in missing values using appropriate methids, we can 
   maintain the correlation and pattern between different features.

2. imputation technique are strightforward to implement, they can applied to various types of data including numberical, categorical and text data.
3. By imputaing missing values, you can reduce the amount of missingness in your dataset. 
   which can lead to imporoved model performance. 
   
   
Disadvantage: 
1. depending on the size of and complexity of the dataset, imputing missing values and signigicantly increase the 
computational complexity and memory requirement. certain imputation, may invlove iterations and introduce additional complutational overhead.
2. Different imputation technique make different assumption about the nature of missingness and the 
   realtionships between variables. If the assumptions do not hold true missing values, leading to erroneous 
   conclusions or biased results.
"""

# %% [markdown]
# Q3. What are the key factors that affect students' performance in exams? How would you go about
# analyzing these factors using statistical techniques?

# %%
"""
The key factor which affect the student'performance in exams are math_score, reading_score, and writing_score
are the facor whcich affect the student'performance in exams . 
math_score=0.92
reading_score=0.98
writing_score=0.94

i can analyzing thest facors by using heatmap method.

# %% [markdown]
# Q4. Describe the process of feature engineering in the context of the student performance data set. How
# did you select and transform the variables for your model?

# %%
"""
The process of feature engineering in the context of student performance dataset are: 
first checking the basic information about dataset like number of row and column in dataset
and datatypes of each features. and than finding out is their any null value present if 
present than by performing the Imputation technique we can resolve this, and then checking is 
their duplicated value present in dataset or not if present than we delete the duplicate value 
by keep first. 
After that spliting the dataset into dependent and independent variable than 
scaling the independent variable by Standard_scaling and main-max scaling so that improve the accuracy of model

# %% [markdown]
# Q5. Load the wine quality data set and perform exploratory data analysis (EDA) to identify the distribution
# of each feature. Which feature(s) exhibit non-normality, and what transformations could be applied to
# these features to improve normality?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('winequality-red.csv')

# %%
df.head(4)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6

# %%
plt.subplots(figsize=(10,8))
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot: >

# %% [markdown]
# ~ Insights : fixed_acidity , citric_acid, sulphates and alcohol are positive correlation with quality of wine, which means as the inceasing the
#              these ingradient increase the test of wine.
#              where as the vlatile acidity , chlorides , density are negatively correlated which decrease the quality of wine as increasing.

# %%
# plt.subplots(1,2,figsize=(15,7))
# plt.subplot(121)
sns.histplot(data=df, x='quality', color='g')
# plt.subplot(121)
sns.catplot(data=df, x='quality', y='alcohol', kind='box')

# %% [markdown]
# Q6. Using the wine quality data set, perform principal component analysis (PCA) to reduce the number of
# features. What is the minimum number of principal components required to explain 90% of the variance in
# the data?

# %%
from sklearn.decomposition import PCA

# %%
df.head(3)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5

# %%
x=df.drop('quality', axis=1)
y=df.iloc[:,-1]

# %%
pca=PCA(n_components=6)

# %%
min_feature=pca.fit_transform(x)

# %%
min_feature.shape
# Out:
# (1599, 6)
